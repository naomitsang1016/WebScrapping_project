# %%
# import libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait

# %%
#Create DataFrame
unit_trust = pd.DataFrame()
code=[]
actual_code=[]

# %%
#get subpage data
URL = "https://investments3.personal-banking.hsbc.com.hk/public/utb/en-gb/fundScreenerResult"

driver = webdriver.Chrome('C:/Users/jacksuen/chromedriver')

driver.get(URL) #replacing the requests.get step
# Out:
# C:\Users\jacksuen\AppData\Local\Temp/ipykernel_8100/2963346838.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:/Users/jacksuen/chromedriver')

# %%
#get the code list of available unit trusts
subhtml = driver.page_source #replacing the html.text

soup = BeautifulSoup(subhtml, "html.parser")
soup.prettify()
code.append(soup.find_all(class_="_2eHeCPAV0L9BJwVMGn7Nu_"))
code=code.copy()

# %%
#click for everypage
for k,v in all_page:   
    for i in range(0,len(v)):
        code.append(v.find_all(class_="_2eHeCPAV0L9BJwVMGn7Nu_")[i].text)

# %%
for i in range(len(code)):
    for j in range(len(code[i])):
        actual_code.append(code[i][j].text)

# %%
#remove closed for subscription in page 14

actual_code = actual_code[:-44]

# %%
#remove ESG text in code
count=0
for i in actual_code:
    if len(i)>6:
        actual_code[count]=actual_code[count][:-3]
    count+=1

# %%
actual_code
# Out:
# ['U61710',
#  'U43242',
#  'U62680',
#  'U62253',
#  'U62254',
#  'U42568',
#  'U61774',
#  'U62464',
#  'U40088',
#  'U61709',
#  'U63147',
#  'U63146',
#  'U62672',
#  'U40111',
#  'U61621',
#  'U61074',
#  'U42276',
#  'U62851',
#  'U61771',
#  'U62577',
#  'U62674',
#  'U61144',
#  'U62668',
#  'U62728',
#  'U62667',
#  'U62671',
#  'U62669',
#  'U43241',
#  'U62670',
#  'U63012',
#  'U62932',
#  'U62239',
#  'U36209',
#  'U39849',
#  'U62786',
#  'U62654',
#  'U63021',
#  'U62944',
#  'U43261',
#  'U43262',
#  'U63007',
#  'U62943',
#  'U62968',
#  'U62675',
#  'U62950',
#  'U62949',
#  'U62948',
#  'U62946',
#  'U63006',
#  'U62868',
#  'U62945',
#  'U63009',
#  'U63011',
#  'U62947',
#  'U62867',
#  'U62969',
#  'U61083',
#  'U62767',
#  'U62766',
#  'U63008',
#  'U63010',
#  'U63019',
#  'U62693',
#  'U62719',
#  'U62983',
#  'U62710',
#  'U63018',
#  'U62720',
#  'U42551',
#  'U62392',
#  'U61793',
#  'U61795',
#  'U62608',
#  'U62962',
#  'U63020',
#  'U61792',
# ...

# %%
unit_trust['Code']=actual_code

# %%
unit_trust.to_csv('code_list.csv', index=False)
